# %% [markdown]
# # Customer churn data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # laod all data

# %%
df = pd.read_csv("Customer Churn.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # Replacing blank with 0 as tenure is 0 and no total charges are recorded

# %%
df["TotalCharges"]= df["TotalCharges"].replace(" ","0")
df["TotalCharges"]= df["TotalCharges"].astype("float")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# # check the dublicate value in data

# %%
df["customerID"].duplicated().sum()
# Out:
# np.int64(0)

# %% [raw]
# #Converted 0 and 1 values of senior citizen to yes/no to make it easier to

# %%
def conv(value):
    if value ==1:
        return "yes"
    else:
        return "no"
df["SeniorCitizen"]= df["SeniorCitizen"].apply(conv)

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
ax=sns.countplot(x='Churn', data =df,width=0.5, color='magenta')
ax.bar_label(ax.containers[0])
plt.title("Count of Customer by Churn")
plt.show()

# %% [raw]
# # From the given pie chart wew can conclute teh 26.54% of our customer have chured out ,
# # not let's explore the reason behind it

# %%
plt.figure(figsize=( 3,4))
gb = df.groupby('Churn').agg({'Churn':"count"})
plt.pie(gb['Churn'],labels=gb.index,autopct="%1.2f%%")
plt.title("Percentage Of Churned Customeres", fontsize=10)
plt.show()

# %%
plt.figure(figsize =(3,4))
ax=sns.countplot(x='gender',data= df,hue="Churn")
plt.bar_label(ax.containers[0])
plt.title("Churn by Gender")
plt.show()

# %%
plt.figure(figsize =(3,4))
ax=sns.countplot(x="SeniorCitizen", data =df)
plt.bar_label(ax.containers[0])
plt.title("Count of Customer by Senior Citizen")
plt.show()

# %%
plt.figure(figsize = (3,4))
ax=sns.countplot(x="SeniorCitizen" ,data= df,hue="Churn")
plt.title("SeniorCitizen by Chrn" )
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])
plt.show()

# %%
# Assuming df is your DataFrame
# Create a cross-tab to get counts for 'SeniorCitizen' and 'Churn'
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'], normalize='index') * 100  # Normalize to get percentage

# Plot a stacked bar chart
ct.plot(kind='bar', stacked=True, figsize=(3, 4), color=['skyblue', 'orange'])

# Add percentage labels on the stacked bar
for i, row in enumerate(ct.iterrows()):
    for j, value in enumerate(row[1]):
        plt.text(j, value/2 + ct.iloc[i,:j].sum(), f'{value:.1f}%', ha='center', va='center', color='black')

# Set the title and labels
plt.title('Churn by SeniorCitizen ')
plt.ylabel('Percentage (%)')
plt.xlabel('SeniorCitizen')
plt.legend(title='Churn', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# # Comparative a greated  pecentage of people in senior citizen category have churned

# %%
plt.figure(figsize = (9,4))
ax=sns.histplot(x="tenure" ,data= df,bins=50,hue="Churn")
#plt.bar_label(ax.containers[0])
plt.show()

# %% [raw]
# # People Who have used our services for a long time have stayed and people who have used out
# # sevice 1 or 2 months have churned

# %%
plt.figure(figsize=(4,4))
ax=sns.countplot(x="Contract",data= df,hue="Churn")
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])
plt.title("Count of Customers by Contract")
plt.show()

# %% [raw]
# # people who have moth to moth contract are lickly to churn then who have 1 or 2 years fo Contract.

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# List of column names to plot
columns = ['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 
           'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

n_cols=3
n_rows=(len(columns)+n_cols-1)// n_cols

fig, axes = plt.subplots(n_rows,n_cols, figsize=(15, n_rows*4))  # 3x3 grid


# Flatten the axes array for easier iteration
axes = axes.flatten()

# Loop through each column and create a countplot in a subplot
for i, col in enumerate(columns):
    sns.countplot(x=col, data=df, ax=axes[i],hue="Churn")
    axes[i].set_title(f'Count plot of {col}')
    axes[i].set_xlabel('')

for j in range(i+1,len(axes)):
    fig.delases(axes[j])
# Adjust layout
plt.tight_layout()
plt.show()

# %% [raw]
# # The image presents nine count plots comparing customer churn (Yes/No) across different telecom services.
# # Notably, customers without OnlineSecurity, TechSupport, or DeviceProtection are more likely to churn.
# # Additionally, customers using Fiber internet service also display a higher churn rate compared to those using DSL.
# # Streaming services (TV and Movies) seem to have a balanced distribution of churn across users.
# #  Overall, the absence of support-related services correlates with a higher likelihood of churn.

# %%
plt.figure(figsize =(6,4))
ax=sns.countplot(x='PaymentMethod',data = df,hue='Churn')
plt.bar_label(ax.containers[0])
plt.bar_label(ax.containers[1])
plt.xticks(rotation=45)
plt.title("Churn Customers by payment Method")
plt.show()

# %% [raw]
# # Customer is likely to Churn when he is using Electronic check payment Method
